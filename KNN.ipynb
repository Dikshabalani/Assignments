# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()

# %% [markdown]
# # Business Problem- 1
# Implement a KNN model to classify the animals in to categories

# %%
df = pd.read_csv("C:/Users/DIKSHA/Downloads/Zoo.csv")

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#   animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    type
# 0     1
# 1     1
# 2     4
# 3     1
# 4     1

# %%
df1.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
sns.factorplot('type', data=df1, kind="count",size = 5,aspect = 2)
# Out:
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As shown in the graphs above, highest number of animals available in Zoo are Type 1 followed by 2, 4 and 7 respectively

# %%
df1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# As shown in the graphs above, majority of the variables are evenly distributed amongst the animals. However some of the variables like airbone, backbone, breathes, venomous, fins, tail and domestic is not evenly distributed (i.e majority of animals either have these variable or dont)

# %% [markdown]
# # Finding correlation between the variables in the data

# %%
cor = df1.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col0,#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col1,#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col2,#T_71287d29_0042_11ec_91b3_e4e7490e3772row3_col3,#T_71287d29_0042_11ec_91b3_e4e7490e3772row4_col4,#T_71287d29_0042_11ec_91b3_e4e7490e3772row5_col5,#T_71287d29_0042_11ec_91b3_e4e7490e3772row6_col6,#T_71287d29_0042_11ec_91b3_e4e7490e3772row7_col7,#T_71287d29_0042_11ec_91b3_e4e7490e3772row8_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col9,#T_71287d29_0042_11ec_91b3_e4e7490e3772row10_col10,#T_71287d29_0042_11ec_91b3_e4e7490e3772row11_col11,#T_71287d29_0042_11ec_91b3_e4e7490e3772row12_col12,#T_71287d29_0042_11ec_91b3_e4e7490e3772row13_col13,#T_71287d29_0042_11ec_91b3_e4e7490e3772row14_col14,#T_71287d29_0042_11ec_91b3_e4e7490e3772row15_col15,#T_71287d29_0042_11ec_91b3_e4e7490e3772row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col1,#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col10{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col2,#T_71287d29_0042_11ec_91b3_e4e7490e3772row5_col14{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col3{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col4,#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col12{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col5,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col10,#T_71287d29_0042_11ec_91b3_e4e7490e3772row16_col14{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col6,#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col14{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col7{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row8_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col9{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col11{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col12{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col13{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col14,#T_71287d29_0042_11ec_91b3_e4e7490e3772row4_col8{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col15{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row0_col16,#T_71287d29_0042_11ec_91b3_e4e7490e3772row7_col10{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col0,#T_71287d29_0042_11ec_91b3_e4e7490e3772row3_col6{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col2,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col3,#T_71287d29_0042_11ec_91b3_e4e7490e3772row15_col0{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col3,#T_71287d29_0042_11ec_91b3_e4e7490e3772row12_col7{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col4{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col5,#T_71287d29_0042_11ec_91b3_e4e7490e3772row10_col7,#T_71287d29_0042_11ec_91b3_e4e7490e3772row14_col16{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col6{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col7{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row13_col7{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col9{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col10{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col11,#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col6{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col13,#T_71287d29_0042_11ec_91b3_e4e7490e3772row7_col15,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row11_col2,#T_71287d29_0042_11ec_91b3_e4e7490e3772row11_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row14_col3{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col14,#T_71287d29_0042_11ec_91b3_e4e7490e3772row16_col1{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col15,#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col13,#T_71287d29_0042_11ec_91b3_e4e7490e3772row12_col1,#T_71287d29_0042_11ec_91b3_e4e7490e3772row13_col6,#T_71287d29_0042_11ec_91b3_e4e7490e3772row14_col5,#T_71287d29_0042_11ec_91b3_e4e7490e3772row15_col14{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row1_col16,#T_71287d29_0042_11ec_91b3_e4e7490e3772row5_col1,#T_71287d29_0042_11ec_91b3_e4e7490e3772row15_col6{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col0,#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col3,#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col7,#T_71287d29_0042_11ec_91b3_e4e7490e3772row3_col2,#T_71287d29_0042_11ec_91b3_e4e7490e3772row3_col10,#T_71287d29_0042_11ec_91b3_e4e7490e3772row5_col9,#T_71287d29_0042_11ec_91b3_e4e7490e3772row6_col14,#T_71287d29_0042_11ec_91b3_e4e7490e3772row7_col1,#T_71287d29_0042_11ec_91b3_e4e7490e3772row7_col4,#T_71287d29_0042_11ec_91b3_e4e7490e3772row8_col10,#T_71287d29_0042_11ec_91b3_e4e7490e3772row8_col16,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col5,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col11,#T_71287d29_0042_11ec_91b3_e4e7490e3772row11_col12,#T_71287d29_0042_11ec_91b3_e4e7490e3772row14_col6,#T_71287d29_0042_11ec_91b3_e4e7490e3772row16_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row16_col13,#T_71287d29_0042_11ec_91b3_e4e7490e3772row16_col15{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col1{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col4,#T_71287d29_0042_11ec_91b3_e4e7490e3772row7_col11,#T_71287d29_0042_11ec_91b3_e4e7490e3772row9_col12{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col5,#T_71287d29_0042_11ec_91b3_e4e7490e3772row6_col5{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_71287d29_0042_11ec_91b3_e4e7490e3772row2_col8,#T_71287d29_0042_11ec_91b3_e4e7490e3772row5_col10,#T_71287d29_0042_11ec_91b3_e4e7490e3772row5_col15{
#             background-color:  #93b5fe;

# %% [markdown]
# As seen in the above graph, there is a high correlation exists between some of the variables. We can use PCA to reduce the hight correlated variables

# %% [markdown]
# # KNN

# %% [markdown]
# Finding optimal number of K

# %%
X = df1.iloc[:,1:17]
y = df1.iloc[:,17]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# As shown in the graph, with K=5 we can achive accurary of 85-90%

# %% [markdown]
# # Applying the algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)
# Out:
# C:\Users\DIKSHA\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"

# %%
score_knn.mean()
# Out:
# 0.8809090909090909

# %%
score_knn.std()*2
# Out:
# 0.12072782037115655

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.8809090909090909]

# %% [markdown]
# # Conclusion

# %% [markdown]
# Support Vector Machine Accuracy: 0.88 (+/- 0.12)

# %% [markdown]
# # Business Problem- 2
# Prepare a model for glass classification using KNN

# %%
df = pd.read_csv("C:/Users/DIKSHA/Downloads/glass.csv")

# %%
df1 = df.copy()

# %%
df1.loc[df['Type'] == 1, 'Type'] = 'building_windows_float_processed'
df1.loc[df['Type'] == 2, 'Type'] = 'building_windows_non_float_processed' 
df1.loc[df['Type'] == 3, 'Type'] = 'vehicle_windows_float_processed' 
df1.loc[df['Type'] == 4, 'Type'] = 'vehicle_windows_non_float_processed' 
df1.loc[df['Type'] == 5, 'Type'] = 'containers' 
df1.loc[df['Type'] == 6, 'Type'] = 'tableware' 
df1.loc[df['Type'] == 7, 'Type'] = 'headlamps'

# %%
df1.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed
# 1  building_windows_float_processed
# 2  building_windows_float_processed
# 3  building_windows_float_processed
# 4  building_windows_float_processed

# %%
df1.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# 50%      8.600000    0.000000    0.000000
# 75%      9.172500    0.000000    0.100000
# max     16.190000    3.150000    0.510000

# %%
sns.factorplot('Type', data=df1, kind="count",size = 5,aspect = 2)
# Out:
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As shown in the graphs above, majority of the glass types are building_windows_float_processed and building_windows_non_float_processed, followed by headlamps

# %%
df1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # Finding correlation between the variables in the data

# %%
cor = df1.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col0,#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col1,#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col2,#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col3,#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col4,#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col5,#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col6,#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col7,#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col1{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col3{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col4,#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col8,#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col1,#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col3,#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col6,#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col7,#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col0,#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col1,#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col5,#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col5{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col6{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col7{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row0_col8{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col0,#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col6{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col2,#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col8{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col3{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col4{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col5{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col6{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row1_col7{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col0{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col4,#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col5{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row2_col8,#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col7{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col0,#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col6{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col1{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col2,#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col4,#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col0{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col5{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col6{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col7,#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col3{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row3_col8{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col1,#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col6,#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col2,#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col4{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col3{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col5{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row4_col8{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col2{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col3{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col4{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col7{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row5_col8{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col0{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col3{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col7{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row6_col8{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col1{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col4{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row7_col5{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col1{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col2{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col3{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col4,#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col7{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f61_e4e7490e3772row8_col5{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_44a22080_0046_11ec_9f6

# %% [markdown]
# As seen in the above graph, there is a high correlation exists between some of the variables. We can use PCA to reduce the hight correlated variables

# %% [markdown]
# # KNN

# %% [markdown]
# Finding optimal number of K

# %%
X = np.array(df1.iloc[:,3:5])
y = np.array(df1['Type'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# we can see that k=4 produces the most accurate results

# %% [markdown]
# # Applying the algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)
# Out:
# C:\Users\DIKSHA\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"

# %%
score_knn.mean()
# Out:
# 0.6127705627705629

# %%
score_knn.std()*2
# Out:
# 0.23547117559816877

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.6127705627705629]

# %% [markdown]
# # Conclusion

# %% [markdown]
# Support Vector Machine Accuracy: 0.61 (+/- 0.23)
