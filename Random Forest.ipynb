# %% [markdown]
# # Business Problem- 1
# A cloth manufacturing company is interested to know about the segment or attributes causes high sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import datasets,tree
from sklearn.tree import export_graphviz 
from sklearn import externals
from io import StringIO
import pydotplus
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/DIKSHA/Downloads/Company_Data (1).csv")

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
df1.describe().T
# Out:
#              count        mean         std   min     25%     50%     75%  \
# Sales        400.0    7.496325    2.824115   0.0    5.39    7.49    9.32
# CompPrice    400.0  124.975000   15.334512  77.0  115.00  125.00  135.00
# Income       400.0   68.657500   27.986037  21.0   42.75   69.00   91.00
# Advertising  400.0    6.635000    6.650364   0.0    0.00    5.00   12.00
# Population   400.0  264.840000  147.376436  10.0  139.00  272.00  398.50
# Price        400.0  115.795000   23.676664  24.0  100.00  117.00  131.00
# Age          400.0   53.322500   16.200297  25.0   39.75   54.50   66.00
# Education    400.0   13.900000    2.620528  10.0   12.00   14.00   16.00
#
#                 max
# Sales         16.27
# CompPrice    175.00
# Income       120.00
# Advertising   29.00
# Population   509.00
# Price        191.00
# Age           80.00
# Education     18.00

# %%
df1.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
df1.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc       object
# Age              int64
# Education        int64
# Urban           object
# US              object
# dtype: object

# %% [markdown]
# # Outlier Check

# %%
ax = sns.boxplot(df1['Sales'])
# Out:
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The data has 2 outlier instances

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['Sales'].skew()))
print("Kurtosis: {}".format(df1['Sales'].kurtosis()))
ax = sns.kdeplot(df1['Sales'],shade=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()
# Out:
# Skew: 0.18556036318721578
# Kurtosis: -0.08087736743346197

# %% [markdown]
# The data is Skwed on the right
# The data has negative Kurtosis

# %%
obj_colum = df1.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(obj_colum,1):
    plt.subplot(2,2,i)
    sns.countplot(data=df1,y=col)
    plt.subplot(2,2,i+1)
    df1[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-7759ffd02bd8>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,i)
# <ipython-input-12-7759ffd02bd8>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,i)

# %%
num_columns = df1.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#              Sales  CompPrice    Income  Advertising  Population     Price  \
# skewness  0.185560  -0.042755  0.049444     0.639586   -0.051227 -0.125286
# kurtosis -0.080877   0.041666 -1.085289    -0.545118   -1.202318  0.451885
#
#                Age  Education
# skewness -0.077182   0.044007
# kurtosis -1.134392  -1.298332

# %%
corr = df1.corr()

# %%
df1 = pd.get_dummies(df1, columns = ['ShelveLoc','Urban','US'])

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Random Forest Model
# Since the target variable is continious, we create a class of the value based on the mean
# <= 7.49 == "Small" and > 7.49 == "large"

# %%
df1["sales"]="small"
df1.loc[df1["Sales"]>7.49,"sales"]="large"
df1.drop(["Sales"],axis=1,inplace=True)

# %%
X = df1.iloc[:,0:14]
y = df1.iloc[:,14]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
y_train.value_counts()
# Out:
# small    164
# large    156
# Name: sales, dtype: int64

# %%
model =RF(n_jobs=4,n_estimators = 150, oob_score =True,criterion ='entropy') 
model.fit(x_train,y_train)
model.oob_score_
# Out:
# 0.796875

# %%
pred_train = model.predict(x_train)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 1.0

# %%
confusion_matrix(y_train,pred_train)
# Out:
# array([[156,   0],
#        [  0, 164]], dtype=int64)

# %%
pred_test = model.predict(x_test)

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.8125

# %%
confusion_matrix(y_test,pred_test)
# Out:
# array([[35,  8],
#        [ 7, 30]], dtype=int64)

# %%
df_t=pd.DataFrame({'Actual':y_test, 'Predicted':pred_test})

# %%
df_t
# Out:
#     Actual Predicted
# 288  small     small
# 83   small     small
# 23   small     small
# 110  large     large
# 117  large     large
# ..     ...       ...
# 227  large     large
# 366  small     small
# 258  small     small
# 349  large     large
# 225  small     large
#
# [80 rows x 2 columns]

# %%
cols = list(df1.columns)

# %%
predictors = cols[0:14]
target = cols[14]

# %%
tree1 = model.estimators_[20]

# %%
dot_data = StringIO()

# %%
export_graphviz(tree1, out_file = dot_data, feature_names =predictors, class_names = target, filled =True,rounded=True,impurity =False,proportion=False,precision =2)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %% [markdown]
# # Conclusion

# %% [markdown]
# Since the accuracy of the Training set is 100% we test the accurancy on the test data which is 81%

# %%
rf_small = RF(n_estimators=10, max_depth = 3)

# %%
rf_small.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
tree_small = rf_small.estimators_[5]

# %%
export_graphviz(tree_small, out_file = dot_data, feature_names = predictors, rounded = True, precision = 1)

# %%
graph_small = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
img = mpimg.imread('C:/Users/DIKSHA/Downloads/company_small.png')

# %%
plt.imshow(img)

# %%
model.feature_importances_
# Out:
# array([0.11490608, 0.09707104, 0.09448185, 0.09510443, 0.21976497,
#        0.11936441, 0.06719316, 0.04420271, 0.07633479, 0.0225458 ,
#        0.01188977, 0.01390191, 0.01132542, 0.01191366])

# %%
fi = pd.DataFrame({'feature': list(x_train.columns),
                   'importance': model.feature_importances_}).\
                    sort_values('importance', ascending = False)

# %%
fi
# Out:
#              feature  importance
# 4              Price    0.219765
# 5                Age    0.119364
# 0          CompPrice    0.114906
# 1             Income    0.097071
# 3         Population    0.095104
# 2        Advertising    0.094482
# 8     ShelveLoc_Good    0.076335
# 6          Education    0.067193
# 7      ShelveLoc_Bad    0.044203
# 9   ShelveLoc_Medium    0.022546
# 11         Urban_Yes    0.013902
# 13            US_Yes    0.011914
# 10          Urban_No    0.011890
# 12             US_No    0.011325

# %% [markdown]
# As seen in the above table Price is most important feature

# %% [markdown]
# # Business Problem- 2

# %% [markdown]
# Use Random Forest to prepare a model on fraud data

# %%
df = pd.read_csv("C:/Users/DIKSHA/Downloads/Fraud_check (1).csv")

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
df1.describe().T
# Out:
#                  count           mean           std      min       25%  \
# Taxable.Income   600.0   55208.375000  26204.827597  10003.0  32871.50
# City.Population  600.0  108747.368333  49850.075134  25779.0  66966.75
# Work.Experience  600.0      15.558333      8.842147      0.0      8.00
#
#                       50%        75%       max
# Taxable.Income    55074.5   78611.75   99619.0
# City.Population  106493.5  150114.25  199778.0
# Work.Experience      15.0      24.00      30.0

# %%
df1.isnull().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
df1.dtypes
# Out:
# Undergrad          object
# Marital.Status     object
# Taxable.Income      int64
# City.Population     int64
# Work.Experience     int64
# Urban              object
# dtype: object

# %% [markdown]
# # Outlier Check

# %%
ax = sns.boxplot(df1['Taxable.Income'])
# Out:
# C:\Users\DIKSHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# There are no outliers in the data

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['Taxable.Income'].skew()))
print("Kurtosis: {}".format(df1['Taxable.Income'].kurtosis()))
ax = sns.kdeplot(df1['Taxable.Income'],shade=True,color='g')
plt.xticks([i for i in range(10000,100000,10000)])
plt.show()
# Out:
# Skew: 0.030014788906377175
# Kurtosis: -1.1997824607083138

# %% [markdown]
# The data is Skwed on the right
# The data has negative Kurtosis

# %%
obj_colum = df1.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(obj_colum,1):
    plt.subplot(2,2,i)
    sns.countplot(data=df1,y=col)
    plt.subplot(2,2,i+1)
    df1[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-60-7759ffd02bd8>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,i)
# <ipython-input-60-7759ffd02bd8>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,i)

# %%
num_columns = df1.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#           Taxable.Income  City.Population  Work.Experience
# skewness        0.030015         0.125009         0.018529
# kurtosis       -1.199782        -1.120154        -1.167524

# %%
df1 = pd.get_dummies(df1, columns = ['Undergrad','Marital.Status','Urban'])

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Random Forest Model
# Since the target variable is continious, we create a class of taxable_income <= 30000 as "Risky" and others are "Good"

# %%
df1['Taxable.Income']=pd.cut(df1['Taxable.Income'],bins=[0,30000,100000],labels=['risky','good'])

# %%
list(df1.columns)
# Out:
# ['Taxable.Income',
#  'City.Population',
#  'Work.Experience',
#  'Undergrad_NO',
#  'Undergrad_YES',
#  'Marital.Status_Divorced',
#  'Marital.Status_Married',
#  'Marital.Status_Single',
#  'Urban_NO',
#  'Urban_YES']

# %%
X = df1.iloc[:,1:10]
y = df1.iloc[:,0]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
y_train.value_counts()
# Out:
# good     376
# risky    104
# Name: Taxable.Income, dtype: int64

# %%
model =RF(n_jobs=4,n_estimators = 150, oob_score =True,criterion ='entropy') 
model.fit(x_train,y_train)
model.oob_score_
# Out:
# 0.7104166666666667

# %%
pred_train = model.predict(x_train)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 1.0

# %%
confusion_matrix(y_train,pred_train)
# Out:
# array([[376,   0],
#        [  0, 104]], dtype=int64)

# %%
pred_test = model.predict(x_test)

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.7583333333333333

# %%
confusion_matrix(y_test,pred_test)
# Out:
# array([[91,  9],
#        [20,  0]], dtype=int64)

# %%
df_t=pd.DataFrame({'Actual':y_test, 'Predicted':pred_test})

# %%
df_t
# Out:
#     Actual Predicted
# 116   good      good
# 449   good      good
# 564   good      good
# 238   good      good
# 52    good      good
# ..     ...       ...
# 494   good      good
# 140  risky      good
# 209   good      good
# 230  risky      good
# 43    good      good
#
# [120 rows x 2 columns]

# %%
cols = list(df1.columns)

# %%
predictors = cols[1:10]
target = cols[0]

# %%
tree1 = model.estimators_[20]

# %%
dot_data = StringIO()

# %%
export_graphviz(tree1, out_file = dot_data, feature_names =predictors, class_names = target, filled =True,rounded=True,impurity =False,proportion=False,precision =2)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %% [markdown]
# # Conclusion

# %% [markdown]
# Since the accuracy of the Training set is 100% we test the accurancy on the test data which is 75%

# %%
rf_small = RF(n_estimators=10, max_depth = 3)

# %%
rf_small.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
tree_small = rf_small.estimators_[5]

# %%
export_graphviz(tree_small, out_file = dot_data, feature_names = predictors, rounded = True, precision = 1)

# %%
graph_small = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
img = mpimg.imread('C:/Users/DIKSHA/Downloads/fraud_small.png')

# %%
plt.imshow(img)

# %%
model.feature_importances_
# Out:
# array([0.5146689 , 0.36372603, 0.01845004, 0.01805507, 0.01864763,
#        0.01868436, 0.01840612, 0.01456826, 0.01479359])

# %%
fi = pd.DataFrame({'feature': list(x_train.columns),
                   'importance': model.feature_importances_}).\
                    sort_values('importance', ascending = False)

# %%
fi
# Out:
#                    feature  importance
# 0          City.Population    0.514669
# 1          Work.Experience    0.363726
# 5   Marital.Status_Married    0.018684
# 4  Marital.Status_Divorced    0.018648
# 2             Undergrad_NO    0.018450
# 6    Marital.Status_Single    0.018406
# 3            Undergrad_YES    0.018055
# 8                Urban_YES    0.014794
# 7                 Urban_NO    0.014568

# %% [markdown]
# As seen in the above table city population is most important feature
